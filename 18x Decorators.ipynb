# %% [markdown]
# <h3 align="left" style="color:blue">DECORATORS</h3>

# %%
import time
def time_it(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args,**kwargs)
        end = time.time()
        print(func.__name__ +" took " + str((end-start)*1000) + "mil sec")
        return result
    return wrapper

@time_it
def calc_square(numbers):
    result = []
    for number in numbers:
        result.append(number*number)
    return result

@time_it
def calc_cube(numbers):
    result = []
    for number in numbers:
        result.append(number*number*number)
    return result

array = range(1,100000)
out_square = calc_square(array)
out_cube = calc_cube(array)
# Out:
# calc_square took 6.889581680297852mil sec
# calc_cube took 10.481834411621094mil sec

# %%
import random
from math import sqrt

class Point:
    def __init__(self, name='anonym_point',x=0,y=0):
        self.name = name
        self.x = x
        self.y = y

    @property
    def coord(self):
        return (self.x, self.y)

    def __repr__(self):
        return ("{} has coordinate {}  {}".format(self.name, self.x, self.y))
    

def makepoint(namepoint):
    return Point(namepoint, random.uniform(0,100), random.uniform(0,100))


def distance_between_points(p1,p2):
    dist = sqrt((p2.x-p1.x)**2 + (p2.y-p1.y)**2)
    print("distance between point ",p1.name," and the point ",p2.name,"  : ",dist)


point1 = makepoint("p1")
point2 = makepoint("p2")

print(point1)
print(point2)

Distance = distance_between_points(point1,point2)
# Out:
# p1 has coordinate 74.3475334069479  76.65355578261234
# p2 has coordinate 86.0529090710782  22.138213657461915
# distance between point  p1  and the point  p2   :  55.7578545718952
