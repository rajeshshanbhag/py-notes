# %%
def maxSeq(data):
    # Write me!
    max=0
    currentseq=1
    print('data',data,len(data))
    if len(data)==0:
        max=0
        return max
    if len(data)==1:
        max=1
        return max
    for i in range(0,len(data)):
        print('a',i,len(data))
        if data[i]>data[i-1]:
            print('b',data[i],data[i-1])
            currentseq+=1
            print('csq',currentseq)
        else:
            max=currentseq
            currentseq=0
    pass


def do_one_test(data):
    print("The max subsequence of {} has length {}".format(data, maxSeq(data)))
    pass

def main():
    do_one_test([])
    do_one_test([1])
    do_one_test([1, 2, 3])
    do_one_test([1, 1, 1])
    do_one_test([1, 2, 1, 2, 3, 4, 1, 2])
    do_one_test([-2, -1, 0, 1, 2])
    do_one_test([1, 2, 3, 1, 2, 3, 4])
    do_one_test([1, 2, 3, 4, 1, 2, 3])
    do_one_test([-10, -4, 0, 5, 34, 89])
    do_one_test([3, 0, 4, 5])
    do_one_test([3, 5, -12])
    do_one_test([1, 2, 1, 3, 5, 6, 2, 5, 8, 12])
    do_one_test([1, 2, 1, 5, 5, 6, 7, 9, 7, 5, 12])
    pass

if __name__ == "__main__":
    main()
    pass
# Out:
# data [] 0
# The max subsequence of [] has length 0
# data [1] 1
# The max subsequence of [1] has length 1
# data [1, 2, 3] 3
# a 0 3
# a 1 3
# b 2 1
# csq 1
# a 2 3
# b 3 2
# csq 2
# The max subsequence of [1, 2, 3] has length None
# data [1, 1, 1] 3
# a 0 3
# a 1 3
# a 2 3
# The max subsequence of [1, 1, 1] has length None
# data [1, 2, 1, 2, 3, 4, 1, 2] 8
# a 0 8
# a 1 8
# b 2 1
# csq 1
# a 2 8
# a 3 8
# b 2 1
# csq 1
# a 4 8
# b 3 2
# csq 2
# a 5 8
# b 4 3
# csq 3
# a 6 8
# a 7 8
# b 2 1
# csq 1
# The max subsequence of [1, 2, 1, 2, 3, 4, 1, 2] has length None
# data [-2, -1, 0, 1, 2] 5
# a 0 5
# a 1 5
# b -1 -2
# csq 1
# a 2 5
# b 0 -1
# csq 2
# a 3 5
# b 1 0
# csq 3
# a 4 5
# b 2 1
# csq 4
# The max subsequence of [-2, -1, 0, 1, 2] has length None
# data [1, 2, 3, 1, 2, 3, 4] 7
# a 0 7
# a 1 7
# b 2 1
# csq 1
# a 2 7
# b 3 2
# csq 2
# a 3 7
# a 4 7
# b 2 1
# csq 1
# a 5 7
# b 3 2
# csq 2
# a 6 7
# b 4 3
# csq 3
# The max subsequence of [1, 2, 3, 1, 2, 3, 4] has length None
# data [1, 2, 3, 4, 1, 2, 3] 7
# a 0 7
# a 1 7
# b 2 1
# csq 1
# a 2 7
# b 3 2
# csq 2
# a 3 7
# b 4 3
# csq 3
# a 4 7
# a 5 7
# b 2 1
# csq 1
# a 6 7
# b 3 2
# csq 2
# The max subsequence of [1, 2, 3, 4, 1, 2, 3] has length None
# data [-10, -4, 0, 5, 34, 89] 6
# a 0 6
# a 1 6
# b -4 -10
# csq 1
# a 2 6
# b 0 -4
# csq 2
# a 3 6
# b 5 0
# csq 3
# a 4 6
# b 34 5
# csq 4
# a 5 6
# b 89 34
# csq 5
# The max subsequence of [-10, -4, 0, 5, 34, 89] has length None
# data [3, 0, 4, 5] 4
# a 0 4
# a 1 4
# a 2 4
# b 4 0
# csq 1
# a 3 4
# b 5 4
# csq 2
# The max subsequence of [3, 0, 4, 5] has length None
# data [3, 5, -12] 3
# a 0 3
# b 3 -12
# csq 2
# a 1 3
# b 5 3
# csq 3
# a 2 3
# The max subsequence of [3, 5, -12] has length None
# data [1, 2, 1, 3, 5, 6, 2, 5, 8, 12] 10
# a 0 10
# a 1 10
# b 2 1
# csq 1
# a 2 10
# a 3 10
# b 3 1
# csq 1
# a 4 10
# b 5 3
# csq 2
# a 5 10
# b 6 5
# csq 3
# a 6 10
# a 7 10
# b 5 2
# csq 1
# a 8 10
# b 8 5
# csq 2
# a 9 10
# b 12 8
# csq 3
# The max subsequence of [1, 2, 1, 3, 5, 6, 2, 5, 8, 12] has length None
# data [1, 2, 1, 5, 5, 6, 7, 9, 7, 5, 12] 11
# a 0 11
# a 1 11
# b 2 1
# csq 1
# a 2 11
# a 3 11
# b 5 1
# csq 1
# a 4 11
# a 5 11
# b 6 5
# csq 1
# a 6 11
# b 7 6
# csq 2
# a 7 11
# b 9 7
# csq 3
# a 8 11
# a 9 11
# a 10 11
# b 12 5
# csq 1
# The max subsequence of [1, 2, 1, 5, 5, 6, 7, 9, 7, 5, 12] has length None
