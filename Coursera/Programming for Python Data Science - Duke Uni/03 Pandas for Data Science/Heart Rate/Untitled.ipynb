# %%
data=[160, 161, 162, 161, 160, 161, 162, 163, 164, 163, 162]
n=1
ma=[]
for i in range(n-1,len(data)):
    #print('a',i,'in range',n-1,'to',len(data))
    add=0
    for j in range(i-n+1,i+1):
        #print('b',j,'in range',i-n+1,'to',i+1)
        #print('data[j]',data[j])
        add+=data[j]
        #print('add',add)
    ma.append(add/n)
    #print(ma)
print(ma)
# Out:
# [160.0, 161.0, 162.0, 161.0, 160.0, 161.0, 162.0, 163.0, 164.0, 163.0, 162.0]

# %%
from count_laps import is_peak_at

# %%
ans1=[]
for i in range(len(data)):
    # see what our code got
    ans = is_peak_at(data, i, n)
    print(data[i],ans)
    if ans==True:
        ans1.append(data[i])
        print('a',ans1)
print(ans1)
# Out:
# 160 False
# 161 False
# 162 True
# a [162]
# 161 False
# 160 False
# 161 False
# 162 False
# 163 False
# 164 True
# a [162, 164]
# 163 False
# 162 False
# [162, 164]

# %%
w=2
map=get_only_peaks(data, w)
