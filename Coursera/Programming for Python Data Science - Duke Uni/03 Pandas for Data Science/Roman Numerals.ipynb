# %% [markdown]
# ### Roman Numerals

# %% [raw]
# For this assignment, you will be writing the function
#
# def roman_numeral(n):
#
# which takes a positive integer n and converts it to a string of *simplified*
# Roman numerals. Roman numerals are a system of writing numbers used by the
# ancient Romans. The system involves letter symbols that represent numbers. Our
# simplified Roman numerals will have the same symbols as real Roman numerals:
#
# M = 1000
# D = 500
# C = 100
# L = 50
# X = 10
# V = 5
# I = 1
#
# However, to keep things simple, our Roman numerals will be purely
# additive. Real Roman numerals allow for "subtractive forms" where a smaller
# number before a bigger number means to subtract, such as IV means four
# (V - I = 5 - 1 = 4). To simplify your task, we are going to only write
# additions, from largest to smallest, so we will write four as IIII
# (1 + 1 + 1 + 1).
#
# Your goal is to take a positive number and return a string that is the
# simplified Roman numeral representation of that string. Note that the largest
# numbers should be first (Ms before Ds, Ds before Cs, and so on). The answer
# should make the best use of the biggest numbers (so 5 should be V, not IIIII).
#
# For example,
#
# roman_numeral(2841)
#
# would return
#
# 'MMDCCCXXXXI'
#
# because
#
# 2841 = 1000 + 1000 + 500 + 100 + 100 + 100 + 10 + 10 + 10 + 10 + 1
#         M      M      D     C     C     C    X    X    X    X    I
#
# Note that your function only needs to deal with positive numbers, we will not
# test it on negative numbers nor zero.
#
# As usual, we have provided you with output.txt, which shows the expected output
# of the provided main.

# %%
def roman_numeral(n: int):
    d = {
        1000: "M",
        500: "D",
        100: "C",
        50: "L",
        10: "X",
        5: "V",
        1: "I",
    }

    ans = ""

    for i in d:
        ans += (n // i) * d[i]
        n %= i
    return ans


if __name__ == "__main__":
    for i in range(1, 25):
        print(roman_numeral(i))
        pass

    print(roman_numeral(50))
    print(roman_numeral(100))
    print(roman_numeral(500))
    print(roman_numeral(1000))
    print(roman_numeral(178))
    print(roman_numeral(2841))
    print(roman_numeral(8492))
