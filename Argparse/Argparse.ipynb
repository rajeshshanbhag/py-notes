# %% [markdown]
# <h3 align="left" style="color:blue">ARGPARSE</h3>

# %%
import argparse

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--number1", help="first number")
    parser.add_argument("--number2", help="second number")
    parser.add_argument("--operation", help="operation", \
                        choices=["add","subtract","multiply"])

    args = parser.parse_args()

    print(args.number1)
    print(args.number2)
    print(args.operation)

    n1=int(args.number1)
    n2=int(args.number2)
    result = None
    if args.operation == "add":
        result=n1+n2
    elif args.operation == "subtract":
        result=n1-n2
    elif args.operation == "multiply":
        result=n1*n2


    print("Result:",result)
# Out:
# usage: ipykernel_launcher.py [-h] [--number1 NUMBER1] [--number2 NUMBER2]
#                              [--operation {add,subtract,multiply}]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\rajes\AppData\Roaming\jupyter\runtime\kernel-cf108606-8fa1-4828-b83e-c31f4a4d01f2.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\rajes\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
