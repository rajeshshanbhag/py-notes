# %% [markdown]
# #### Your data includes not only numerical data, but also text, images, geometric objects, or any other type of data (i.e., your data are heterogeneous). In these situations, numpy may not be appropriate, while pandas can easily organize, manipulate, and analyze this kind of "mixed data."

# %% [markdown]
# #### If you have tabular data — that is, data organized into rows and columns, as in a spreadsheet — it is often easier in pandas to describe, summarize, query, and visualize the data than the equivalent processes with numpy.

# %%
import numpy as np
a = np.array([6.1,150.0,25,'A-'])
b = np.array([5.6,122.0,29,'B+'])
c = a + b
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       2 a = np.array([6.1,150.0,25,'A-'])
#       3 b = np.array([5.6,122.0,29,'B+'])
# ----> 4 c = a + b
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> None

# %%
import pandas as pd

a = pd.Series([6.1, 150.0, 25, "A-"])
b = pd.Series([5.6, 122.0, 29, "B+"])
c = a + b
c
# Out:
# 0     11.7
# 1    272.0
# 2       54
# 3     A-B+
# dtype: object
