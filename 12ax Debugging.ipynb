# %% [markdown]
# <h3 style="color:blue" align="left">DEBUGGING</h3>

# %% [markdown]
# #### Assert statement

# %%
x = "hello"

#if condition returns True, then nothing happens:
assert x == "hello"

#if condition returns False, AssertionError is raised:
assert x == "goodbye", "value should be 'hello'"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 7
#       4 assert x == "hello"
#       6 #if condition returns False, AssertionError is raised:
# ----> 7 assert x == "goodbye", "value should be 'hello'"
#
# AssertionError: value should be 'hello'
