# %% [markdown]
# <h3 align="left" style="color:blue">COMPREHENSION</h3>

# %%
#without list comprehension
numbers = [1,2,3,4,5]
sqr_numbers = []

for n in numbers:
    sqr_numbers.append(n*n)
print(sqr_numbers)

#with list comprehension
sqr_numbers = [n*n for n in numbers]
sqr_numbers
# Out:
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %%
# Dictionary Comprehension
integer = [0, 1, 2, 3, 4]
binary = ["0", "1", "10", "11", "100"]

z = zip(integer, binary)
binary_dict = {integer: binary for integer, binary in z}

print(binary_dict)

# List Comprehension
integer = [1, -1, 2, 3, 5, 0, -7]
additive_inverse = [-1*i for i in integer]
print(additive_inverse)

# Set Comprehension
integer = [1, -1, 2, -2, 3, -3]
sq_set = {i*i for i in integer}
print(sq_set)
# Out:
# {0: '0', 1: '1', 2: '10', 3: '11', 4: '100'}
# [-1, 1, -2, -3, -5, 0, 7]
# {1, 4, 9}

# %% [markdown]
# #### Comprehension offers better performance

# %%
import time

long_list = range(10000000)
sqr_list = []

start = time.time()
for n in long_list:
    sqr_list.append(n*n)
end = time.time()
print("Time taken by for loop:", (end-start))
# Out:
# Time taken by for loop: 1.3721487522125244

# %%
start = time.time()
sqr_list = [n*n for n in long_list]
end = time.time()
print("Time taken by list comprehension:", (end-start))
# Out:
# Time taken by list comprehension: 0.8637256622314453

# %% [markdown]
# #### List comprehension

# %%
prices = [120, 99, 150, 80, 200]
discounted_prices = [price * 0.9 for price in prices if price > 100]
print(discounted_prices)
# Out:
# [108.0, 135.0, 180.0]

# %% [markdown]
# #### Dictionary Comprehension

# %%
names = ["Alice", "Bob", "Charlie"]
ages = [25, 30, 35]
name_age_dict = {names[i]: ages[i] for i in range(len(names))}
print(name_age_dict)
# Out:
# {'Alice': 25, 'Bob': 30, 'Charlie': 35}

# %% [markdown]
# #### Set comprehension

# %%
transactions = [
    {'customer_name': "Mira", "amount": 56, "date": "2024-08-01"},
    {'customer_name': "Mira", "amount": 12.3, "date": "2024-09-05"},
    {'customer_name': "Mohan", "amount": 21, "date": "2024-09-03"},
    {'customer_name': "Mohan", "amount": 36.8, "date": "2024-09-10"},
    {'customer_name': "Lucy", "amount": 66.3, "date": "2024-09-10"}
]

customers = set()

customers = {trans['customer_name'] for trans in transactions}
customers
# Out:
# {'Lucy', 'Mira', 'Mohan'}
