# %% [markdown]
# #### Index Alignment

# %%
import pandas as pd

# %%
a = pd.Series(data=[1, 2, 3.2], index=["mon", "tue", "wed"])
b = pd.Series(data=[4.0, 5, 6], index=["tue", "wed", "fri"])
a*b
# Out:
# fri     NaN
# mon     NaN
# tue     8.0
# wed    16.0
# dtype: float64
