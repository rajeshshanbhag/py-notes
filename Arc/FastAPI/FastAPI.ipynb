# %%
pip install FastAPI
# Out:
# Requirement already satisfied: FastAPI in c:\users\rajes\anaconda3\lib\site-packages (0.115.12)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\rajes\anaconda3\lib\site-packages (from FastAPI) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\rajes\anaconda3\lib\site-packages (from FastAPI) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rajes\anaconda3\lib\site-packages (from FastAPI) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rajes\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->FastAPI) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rajes\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->FastAPI) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\rajes\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->FastAPI) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rajes\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->FastAPI) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rajes\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->FastAPI) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install uvicorn
# Out:
# Collecting uvicorn
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click>=7.0 in c:\users\rajes\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\rajes\anaconda3\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in c:\users\rajes\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Installing collected packages: uvicorn
# Successfully installed uvicorn-0.34.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastapi uvicorn nest_asyncio pyngrok
# Out:
# Requirement already satisfied: fastapi in c:\users\rajes\anaconda3\lib\site-packages (0.115.12)
# Requirement already satisfied: uvicorn in c:\users\rajes\anaconda3\lib\site-packages (0.34.2)
# Requirement already satisfied: nest_asyncio in c:\users\rajes\anaconda3\lib\site-packages (1.6.0)
# Collecting pyngrok
#   Downloading pyngrok-7.2.5-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\rajes\anaconda3\lib\site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\rajes\anaconda3\lib\site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rajes\anaconda3\lib\site-packages (from fastapi) (4.11.0)
# Requirement already satisfied: click>=7.0 in c:\users\rajes\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\rajes\anaconda3\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\rajes\anaconda3\lib\site-packages (from pyngrok) (6.0.1)
# Requirement already satisfied: colorama in c:\users\rajes\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rajes\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rajes\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\rajes\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rajes\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rajes\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.0)
# Downloading pyngrok-7.2.5-py3-none-any.whl (23 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
#### simple example

# %%
from typing import Union
from fastapi import FastAPI

app = FastAPI()

@app.get("")
def read_root():
    return {"Hello": "World"}

@app.get("/items/{item_id}")
def read_item(item_id: int, q: Union[str, None] = None):
    return {"item_id": item_id, "q": q}

# %%
import nest_asyncio
import uvicorn
from pyngrok import ngrok

# %%
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ngrok_tunnel = ngrok.connect(8000)
#       2 print('Public URL:', ngrok_tunnel.public_url)
#
# File ~\anaconda3\Lib\site-packages\pyngrok\ngrok.py:350, in connect(addr, proto, name, pyngrok_config, **options)
#     346 _upgrade_legacy_params(pyngrok_config, options)
#     348 logger.info(f"Opening tunnel named: {name}")
# --> 350 api_url = get_ngrok_process(pyngrok_config).api_url
#     352 logger.debug(f"Creating tunnel with options: {options}")
#     354 tunnel = NgrokTunnel(api_request(f"{api_url}/api/tunnels", method="POST", data=options,
#     355                                  timeout=pyngrok_config.request_timeout),
#     356                      pyngrok_config, api_url)
#
# File ~\anaconda3\Lib\site-packages\pyngrok\ngrok.py:172, in get_ngrok_process(pyngrok_config)
#     168     pyngrok_config = conf.get_default()
#     170 install_ngrok(pyngrok_config)
# --> 172 return process.get_process(pyngrok_config)
#
# File ~\anaconda3\Lib\site-packages\pyngrok\process.py:265, in get_process(pyngrok_config)
#     262 if is_process_running(pyngrok_config.ngrok_path):
#     263     return _current_processes[pyngrok_config.ngrok_path]
# --> 265 return _start_process(pyngrok_config)
#
# File ~\anaconda3\Lib\site-packages\pyngrok\process.py:394, in _start_process(pyngrok_config)
#     392 elif pyngrok_config.start_new_session:
#     393     logger.warning("Ignoring start_new_session=True, which requires POSIX")
# --> 394 proc = subprocess.Popen(start, **popen_kwargs)
#     395 atexit.register(_terminate_process, proc)
#     397 logger.debug(f"ngrok process starting with PID: {proc.pid}")
#
# File ~\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\anaconda3\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# PermissionError: [WinError 5] Access is denied

# %%
from fastapi import FastAPI

from enum import Enum

app = FastAPI()

food_items = {
    'indian' : [ "Samosa", "Dosa" ],
    'american' : [ "Hot Dog", "Apple Pie"],
    'italian' : [ "Ravioli", "Pizza"]
}

class AvailableCuisines(str, Enum):
    indian = "indian"
    american = "american"
    italian = "italian"

@app.get("/get_items/{cuisine}")
def get_items(cuisine: AvailableCuisines):
    return food_items.get(cuisine)

coupon_code = {
    1: '10%',
    2: '20%',
    3: '30%'
}

@app.get("/get_coupon/{code}")
async def get_items(code: int):
    return { 'discount_amount': coupon_code.get(code) }
