# %%
import requests

topic=input("topic: ")
api_key="94c5d9f6f4564dd2b7c43ebcb0b6d67e"
url="https://newsapi.org/v2/everything?q={topic}&from=2024-08-18&sortBy=publishedAt&apiKey=94c5d9f6f4564dd2b7c43ebcb0b6d67e&language=en"

r= requests.get(url)
content=r.json()
print(content)
body=""
for i in content['articles'][:20]:
    if i['description'] is not None:
        body='Subject: Todays news'+'\n'+body+i['title']+'\n'+i['description']+'\n'+i['url']+2*'\n'
        #print(body)

import smtplib, ssl


def send_email(message):
    host = "smtp.gmail.com"
    port = 465

    username = "rajeshshanbhag@gmail.com"
    password = "mqzczcnnnwflsxwf"

    receiver = "rajeshshanbhag@gmail.com"
    context = ssl.create_default_context()

    with smtplib.SMTP_SSL(host, port, context=context) as server:
        server.login(username, password)
        server.sendmail(username, receiver, message)

body=body.encode('utf-8')
send_email(body)
print("sent")
# Out:
# topic:  tesla
# ...

# %%
import requests

topic=input("topic: ")
api_key="Ybf3JeZDkmFwBiRVxB0pi2gUrQ1yldCbj3HxEI3w"
url="https://api.nasa.gov/planetary/apod?"

r= requests.get(url)
content=r.json()
print(content)
body=""
for i in content['articles'][:20]:
    if i['description'] is not None:
        body='Subject: Todays news'+'\n'+body+i['title']+'\n'+i['description']+'\n'+i['url']+2*'\n'
        #print(body)

import smtplib, ssl


def send_email(message):
    host = "smtp.gmail.com"
    port = 465

    username = "rajeshshanbhag@gmail.com"
    password = "mqzczcnnnwflsxwf"

    receiver = "rajeshshanbhag@gmail.com"
    context = ssl.create_default_context()

    with smtplib.SMTP_SSL(host, port, context=context) as server:
        server.login(username, password)
        server.sendmail(username, receiver, message)

body=body.encode('utf-8')
send_email(body)
print("sent")
